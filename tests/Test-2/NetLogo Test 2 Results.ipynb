# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  

rows_to_keep = [5,6]
ct_G = pd.read_csv('C:\Users\Daft\Desktop\NetLogo\tests\Test-1\Test 1 - Galvez\Test 1 Galvez - Contact Tracing.csv', skiprows = 21, usecols=[0,1,4,5,8,9,12,13,16,17,20,21])
dc_G = pd.read_csv('C:\Users\Daft\Desktop\NetLogo\tests\Test-1\Test 1 - Galvez\Test 1 Galvez - Daily Chart.csv', skiprows = 19)
dd_G = pd.read_csv('C:\Users\Daft\Desktop\NetLogo\tests\Test-1\Test 1 - Galvez\Test 1 Galvez - Daily Deaths.csv', skiprows = 17)
dtc_G = pd.read_csv('C:\Users\Daft\Desktop\NetLogo\tests\Test-1\Test 1 - Galvez\Test 1 Galvez - Daily total cases.csv', skiprows = 16)
dtr_G = pd.read_csv('C:\Users\Daft\Desktop\NetLogo\tests\Test-1\Test 1 - Galvez\Test 1 Galvez - Daily total recoveries.csv', skiprows = 16)
sod_G = pd.read_csv('C:\Users\Daft\Desktop\NetLogo\tests\Test-1\Test 1 - Galvez\Test 1 Galvez - Spread of Disease.csv', skiprows = 16)


ct_G2 = pd.read_csv('Test 2 - Galvez\Test 2 Galvez - Contact Tracing.csv', skiprows = 21, usecols=[0,1,4,5,8,9,12,13,16,17,20,21])
dc_G2 = pd.read_csv('Test 2 - Galvez\Test 2 Galvez - Daily Chart.csv', skiprows = 19)
dd_G2 = pd.read_csv('Test 2 - Galvez\Test 2 Galvez - Daily Deaths.csv', skiprows = 17)
dtc_G2 = pd.read_csv('Test 2 - Galvez\Test 2 Galvez - Daily total cases.csv', skiprows = 16)
dtr_G2 = pd.read_csv('Test 2 - Galvez\Test 2 Galvez - Daily total recoveries.csv', skiprows = 16)
sod_G2 = pd.read_csv('Test 2 - Galvez\Test 2 Galvez - Spread of Disease.csv', skiprows = 16)
# Out:
#   File "C:\Users\Daft\AppData\Local\Temp\ipykernel_36136\1153976373.py", line 7
#     ct_G = pd.read_csv('C:\Users\Daft\Desktop\NetLogo\tests\Test-1\Test 1 - Galvez\Test 1 Galvez - Contact Tracing.csv', skiprows = 21, usecols=[0,1,4,5,8,9,12,13,16,17,20,21])
#                                                                                                                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# # Spread of Disease in Ticks

# %%
plt.figure(figsize=(12,8))
plt.plot(sod_G2.x, sod_G2.y)
plt.legend('Galvez')
plt.title('Spread of Disease in Ticks')
plt.xlabel('time')
plt.ylabel('infected')
plt.show()

# %% [markdown]
# ## Convert Ticks to Days in Spread of Disease

# %%
sodGdays2 = sod_G2.groupby(sod_G2.index // 480).sum()

plt.figure(figsize=(12,8))
plt.plot(sodGdays2.y)
plt.title('Spread of Disease in Days')
plt.legend(['Galvez'])
plt.xlabel('days')
plt.ylabel('infected')
plt.show()
